# %% [markdown]
# # Imports:

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
import os
import pandas as pd
import librosa
import numpy as np
from sklearn import metrics
import scipy
import scipy.signal
import scipy.fftpack

# %% [markdown]
# # Data Frames:

# %% [markdown]
# ## Dina Hussam

# %%
filelist = os.listdir('voice_dataset//Dina Hussam')
df_dina = pd.DataFrame(filelist)
df_dina['label']='0'
df_dina = df_dina.rename(columns={0:'file'})
df_dina
# Out:
#                  file label
# 0         dina_10.wav     0
# 1         dina_11.wav     0
# 2         dina_12.wav     0
# 3         dina_13.wav     0
# 4         dina_14.wav     0
# 5         dina_15.wav     0
# 6         dina_16.wav     0
# 7         dina_17.wav     0
# 8         dina_18.wav     0
# 9         dina_19.wav     0
# 10        dina_20.wav     0
# 11        dina_21.wav     0
# 12        dina_22.wav     0
# 13        dina_23.wav     0
# 14        dina_24.wav     0
# 15        dina_25.wav     0
# 16        dina_26.wav     0
# 17        dina_27.wav     0
# 18        dina_28.wav     0
# 19        dina_29.wav     0
# 20        dina_30.wav     0
# 21         dina_9.wav     0
# 22   dina_wrong_1.wav     0
# 23  dina_wrong_10.wav     0
# 24  dina_wrong_11.wav     0
# 25  dina_wrong_12.wav     0
# 26  dina_wrong_13.wav     0
# 27  dina_wrong_14.wav     0
# 28  dina_wrong_15.wav     0
# 29  dina_wrong_16.wav     0
# 30  dina_wrong_17.wav     0
# 31  dina_wrong_18.wav     0
# 32  dina_wrong_19.wav     0
# 33   dina_wrong_2.wav     0
# 34  dina_wrong_20.wav     0
# 35   dina_wrong_3.wav     0
# 36   dina_wrong_4.wav     0
# 37   dina_wrong_5.wav     0
# 38   dina_wrong_6.wav     0
# 39   dina_wrong_7.wav     0
# 40   dina_wrong_8.wav     0
# 41   dina_wrong_9.wav     0

# %% [markdown]
# ## Romisaa Elsaidy

# %%
filelist= os.listdir('voice_dataset//Romisaa Elsaidy')
df_romisaa = pd.DataFrame(filelist)
df_romisaa['label']='1'
df_romisaa = df_romisaa.rename(columns={0:'file'})
df_romisaa
# Out:
#               file label
# 0   close (14).wav     1
# 1   close (15).wav     1
# 2   close (16).wav     1
# 3     open (1).wav     1
# 4    open (10).wav     1
# 5    open (11).wav     1
# 6    open (12).wav     1
# 7    open (13).wav     1
# 8    open (14).wav     1
# 9    open (15).wav     1
# 10   open (16).wav     1
# 11   open (17).wav     1
# 12   open (18).wav     1
# 13   open (19).wav     1
# 14    open (2).wav     1
# 15   open (20).wav     1
# 16   open (21).wav     1
# 17   open (22).wav     1
# 18    open (3).wav     1
# 19    open (4).wav     1
# 20    open (5).wav     1
# 21    open (6).wav     1
# 22    open (7).wav     1
# 23    open (8).wav     1
# 24    open (9).wav     1
# 25    wrong-01.wav     1
# 26    wrong-02.wav     1
# 27    wrong-03.wav     1
# 28    wrong-04.wav     1
# 29    wrong-05.wav     1
# 30    wrong-06.wav     1
# 31    wrong-07.wav     1
# 32    wrong-08.wav     1
# 33    wrong-09.wav     1
# 34    wrong-10.wav     1
# 35    wrong-11.wav     1
# 36    wrong-12.wav     1
# 37    wrong-13.wav     1
# 38    wrong-14.wav     1
# 39    wrong-15.wav     1
# 40    wrong-16.wav     1
# 41    wrong-17.wav     1

# %% [markdown]
# ## Youssef Shaban

# %%
filelist = os.listdir('voice_dataset//Youssef Shaban')
df_youssef = pd.DataFrame(filelist)
df_youssef['label']='2'
df_youssef = df_youssef.rename(columns={0:'file'})
df_youssef
# Out:
#               file label
# 0    youssef_1.wav     2
# 1   youssef_10.wav     2
# 2   youssef_11.wav     2
# 3   youssef_12.wav     2
# 4   youssef_13.wav     2
# 5   youssef_14.wav     2
# 6   youssef_15.wav     2
# 7   youssef_16.wav     2
# 8   youssef_17.wav     2
# 9   youssef_18.wav     2
# 10  youssef_19.wav     2
# 11   youssef_2.wav     2
# 12  youssef_20.wav     2
# 13  youssef_21.wav     2
# 14  youssef_22.wav     2
# 15  youssef_23.wav     2
# 16  youssef_24.wav     2
# 17  youssef_25.wav     2
# 18  youssef_26.wav     2
# 19  youssef_27.wav     2
# 20  youssef_28.wav     2
# 21  youssef_29.wav     2
# 22   youssef_3.wav     2
# 23  youssef_30.wav     2
# 24  youssef_31.wav     2
# 25  youssef_32.wav     2
# 26  youssef_33.wav     2
# 27  youssef_34.wav     2
# 28  youssef_35.wav     2
# 29  youssef_36.wav     2
# 30  youssef_37.wav     2
# 31  youssef_38.wav     2
# 32  youssef_39.wav     2
# 33   youssef_4.wav     2
# 34  youssef_40.wav     2
# 35  youssef_41.wav     2
# 36  youssef_42.wav     2
# 37   youssef_5.wav     2
# 38   youssef_6.wav     2
# 39   youssef_7.wav     2
# 40   youssef_8.wav     2
# 41   youssef_9.wav     2

# %% [markdown]
# ## Others

# %%
filelist=os.listdir('voice_dataset//Other')
#read them into pandas
df_others = pd.DataFrame(filelist)
df_others['label']='3'
df_others = df_others.rename(columns={0:'file'})
df_others
# Out:
#                         file label
# 0          abdelrahmans1.wav     3
# 1          abdelrahmans2.wav     3
# 2         abdelrahmans28.wav     3
# 3         abdelrahmans29.wav     3
# 4         abdelrahmans30.wav     3
# 5   AuphonicRecording_27.wav     3
# 6   AuphonicRecording_28.wav     3
# 7   AuphonicRecording_29.wav     3
# 8   AuphonicRecording_30.wav     3
# 9                close12.wav     3
# 10               close13.wav     3
# 11               close14.wav     3
# 12               close15.wav     3
# 13               kamel14.wav     3
# 14               kamel15.wav     3
# 15                open11.wav     3
# 16                open12.wav     3
# 17                open13.wav     3
# 18                open14.wav     3
# 19                open15.wav     3
# 20          Recording 11.wav     3
# 21          Recording 12.wav     3
# 22          Recording 13.wav     3
# 23          Recording 14.wav     3
# 24          Recording 15.wav     3
# 25          Recording 16.wav     3
# 26          Recording 17.wav     3
# 27          Recording 18.wav     3
# 28          Recording 19.wav     3
# 29          Recording 20.wav     3
# 30          Recording 21.wav     3
# 31          Recording 22.wav     3
# 32          Recording 23.wav     3
# 33          Recording 24.wav     3
# 34          Recording 25.wav     3
# 35                sama11.wav     3
# 36                sama12.wav     3
# 37                sama13.wav     3
# 38                sama14.wav     3
# 39                sama15.wav     3
# 40                sama29.wav     3
# 41                sama30.wav     3

# %% [markdown]
# # Concatenate the Data Frames:

# %%
df = pd.concat([df_dina, df_romisaa,df_youssef,df_others], ignore_index=True)
df.head()
# Out:
#           file label
# 0  dina_10.wav     0
# 1  dina_11.wav     0
# 2  dina_12.wav     0
# 3  dina_13.wav     0
# 4  dina_14.wav     0

# %% [markdown]
# # Extract Features:

# %% [markdown]
# ## MFCC Features

# %%
def power_to_db(S, ref=1.0, amin=1e-10, top_db=80.0):
    S = np.asarray(S)
    magnitude = S
    ref_value = np.abs(1.0)
    log_spec = 10.0 * np.log10(np.maximum(1e-10, magnitude))
    log_spec -= 10.0 * np.log10(np.maximum(1e-10, ref_value))
    log_spec = np.maximum(log_spec, log_spec.max() - top_db)
    return log_spec

# %%
def expand_to(x, ndim, axes):
    # Force axes into a tuple
    try:
        axes = tuple(axes)
    except TypeError:
        axes = tuple([axes])

    shape = [1] * ndim
    for i, axi in enumerate(axes):
        shape[axi] = x.shape[i]

    return x.reshape(shape)

# %%
def mfcc(y=None, sr=22050, S=None, n_mfcc=20, dct_type=2, norm="ortho", lifter=0, **kwargs):
    if S is None:
        # multichannel behavior may be different due to relative noise floor differences between channels
        S = power_to_db(melspectrogram(y=y, sr=sr, **kwargs))

    M = scipy.fftpack.dct(S, axis=-2, type=dct_type, norm=norm)[..., :n_mfcc, :]

    if lifter > 0:
        # shape lifter for broadcasting
        LI = np.sin(np.pi * np.arange(1, 1 + n_mfcc, dtype=M.dtype) / lifter)
        LI = expand_to(LI, ndim=S.ndim, axes=-2)

        M *= 1 + (lifter / 2) * LI
        return M
    elif lifter == 0:
        return M

# %% [markdown]
# ## Chroma STFT Features

# %% [markdown]
# ## Melspectrogram Features

# %%
def _spectrogram(y=None, S=None, n_fft=2048, hop_length=512, power=1, win_length=None, window="hann", center=True,
                 pad_mode="constant"):

    if S is not None:
        # Infer n_fft from spectrogram shape, but only if it mismatches
        if n_fft // 2 + 1 != S.shape[-2]:
            n_fft = 2 * (S.shape[-2] - 1)
    else:
        # Otherwise, compute a magnitude spectrogram from input
        S = (
            np.abs(
                librosa.stft(
                    y,
                    n_fft=n_fft,
                    hop_length=hop_length,
                    win_length=win_length,
                    center=center,
                    window=window,
                    pad_mode=pad_mode,
                )
            )
            ** power
        )

    return S, n_fft

# %%
def fft_frequencies(sr=22050, n_fft=2048):
    return np.fft.rfftfreq(n=n_fft, d=1.0 / sr)

# %%
def mel_frequencies(n_mels=128, fmin=0.0, fmax=11025.0, htk=False):
    # 'Center freqs' of mel bands - uniformly spaced between limits
    min_mel = hz_to_mel(fmin, htk=htk)
    max_mel = hz_to_mel(fmax, htk=htk)

    mels = np.linspace(min_mel, max_mel, n_mels)

    return mel_to_hz(mels, htk=htk)

# %%
def hz_to_mel(frequencies, htk=False):
    frequencies = np.asanyarray(frequencies)

    if htk:
        return 2595.0 * np.log10(1.0 + frequencies / 700.0)

    # Fill in the linear part
    f_min = 0.0
    f_sp = 200.0 / 3

    mels = (frequencies - f_min) / f_sp

    # Fill in the log-scale part

    min_log_hz = 1000.0  # beginning of log region (Hz)
    min_log_mel = (min_log_hz - f_min) / f_sp  # same (Mels)
    logstep = np.log(6.4) / 27.0  # step size for log region

    if frequencies.ndim:
        # If we have array data, vectorize
        log_t = frequencies >= min_log_hz
        mels[log_t] = min_log_mel + np.log(frequencies[log_t] / min_log_hz) / logstep
    elif frequencies >= min_log_hz:
        # If we have scalar data, heck directly
        mels = min_log_mel + np.log(frequencies / min_log_hz) / logstep

    return mels

# %%
def mel_to_hz(mels, htk=False):
    mels = np.asanyarray(mels)

    if htk:
        return 700.0 * (10.0 ** (mels / 2595.0) - 1.0)

    # Fill in the linear scale
    f_min = 0.0
    f_sp = 200.0 / 3
    freqs = f_min + f_sp * mels

    # And now the nonlinear scale
    min_log_hz = 1000.0  # beginning of log region (Hz)
    min_log_mel = (min_log_hz - f_min) / f_sp  # same (Mels)
    logstep = np.log(6.4) / 27.0  # step size for log region

    if mels.ndim:
        # If we have vector data, vectorize
        log_t = mels >= min_log_mel
        freqs[log_t] = min_log_hz * np.exp(logstep * (mels[log_t] - min_log_mel))
    elif mels >= min_log_mel:
        # If we have scalar data, check directly
        freqs = min_log_hz * np.exp(logstep * (mels - min_log_mel))

    return freqs

# %%
def mel(sr, n_fft, n_mels=128, fmin=0.0, fmax=None, htk=False, norm="slaney", dtype=np.float32):
    if fmax is None:
        fmax = float(sr) / 2

    # Initialize the weights
    n_mels = int(n_mels)
    weights = np.zeros((n_mels, int(1 + n_fft // 2)), dtype=dtype)

    # Center freqs of each FFT bin
    fftfreqs = fft_frequencies(sr=sr, n_fft=n_fft)

    # 'Center freqs' of mel bands - uniformly spaced between limits
    mel_f = mel_frequencies(n_mels + 2, fmin=fmin, fmax=fmax, htk=htk)

    fdiff = np.diff(mel_f)
    ramps = np.subtract.outer(mel_f, fftfreqs)

    for i in range(n_mels):
        # lower and upper slopes for all bins
        lower = -ramps[i] / fdiff[i]
        upper = ramps[i + 2] / fdiff[i + 1]

        # .. then intersect them with each other and zero
        weights[i] = np.maximum(0, np.minimum(lower, upper))

    if norm == "slaney":
        # Slaney-style mel is scaled to be approx constant energy per channel
        enorm = 2.0 / (mel_f[2 : n_mels + 2] - mel_f[:n_mels])
        weights *= enorm[:, np.newaxis]
    else:
        weights = normalize(weights, norm=norm, axis=-1)

    return weights

# %%
def melspectrogram(y=None, sr=22050, S=None, n_fft=2048, hop_length=512, win_length=None, window="hann", center=True,
                   pad_mode="constant", power=2.0, **kwargs):

    S, n_fft = _spectrogram(y=y, S=S, n_fft=n_fft, hop_length=hop_length, power=power, win_length=win_length, window=window,
                            center=center,pad_mode=pad_mode,)

    # Build a Mel filter
    mel_basis = mel(sr=sr, n_fft=n_fft, **kwargs)

    return np.einsum("...ft,mf->...mt", S, mel_basis, optimize=True)

# %% [markdown]
# ## Spectral Contrast Features

# %% [markdown]
# ## tonnetz Features

# %% [markdown]
# ## Main Features:

# %%
def extract_features(files):
    global name
    try:
        # Sets the name to be the path to where the file is in my computer
        file_name = os.path.join(os.path.abspath('voice_dataset/{}').format(name)+ ('\\') +str(files['file']))

        # Loads the audio file as a floating point time series and assigns the default sample rate
        # Sample rate is set to 22050 by default
        X, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        
    except:
        print(files['file'])
        
        # Generate Mel-frequency cepstral coefficients (MFCCs) from a time series 
    mfccs = np.mean(mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)

        # Generates a Short-time Fourier transform (STFT) to use in the chroma_stft
    stft = np.abs(librosa.stft(X))

        # Computes a chromagram from a waveform or power spectrogram.
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)

        # Computes a mel-scaled spectrogram.
    mel = np.mean(melspectrogram(X, sr=sample_rate).T,axis=0)

        # Computes spectral contrast
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)

        # Computes the tonal centroid features (tonnetz)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)

        # We add also the classes of each file as a label at the end
    if name == "all":
        label = files.label
        return mfccs, chroma, mel, contrast, tonnetz, label
    else:
        return mfccs, chroma, mel, contrast, tonnetz

# %% [markdown]
# # Concatenate Feature Function:

# %%
def feat(features_label):
    features = []
    for i in range(0, len(features_label)):
        features.append(np.concatenate((features_label[i][0], features_label[i][1], 
                features_label[i][2], features_label[i][3],
                features_label[i][4]), axis=0))
    return features

# %%
name = "all"
features_label = df.apply(extract_features, axis=1)
features = feat(features_label)
# Out:
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=882
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=855
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=827
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1020
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=965
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=938
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=910
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=993
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=672
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=336
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=632
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=316
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=848
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=424
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=680
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=340
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=576
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=288
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=608
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=304
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=568
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=284
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=704
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=352
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=728
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=364
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=560
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=280
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=696
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=348
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=776
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=388
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=824
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=412
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=584
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=292
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=664
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=332
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=552
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=276
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=888
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=444
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=856
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=428
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=880
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=440
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=784
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=392
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=896
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=448
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=520
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=832
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=416
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=808
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=404
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=648
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=324
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=912
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=456
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=600
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=300
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=656
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=328
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=980
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=490
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=800
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=400
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=744
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=372
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=512
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=792
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=396
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=984
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=492
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=904
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=452
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=976
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=488
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=528
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=960
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=480
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=544
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=272
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=536
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=268
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=688
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=344
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=936
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=468
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=720
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=360
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=768
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=384
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=944
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=472
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=717
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=772
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=745
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=579
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=524
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=633
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=613
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=628
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=663
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=567
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=532
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1013
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=507
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=765
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=662
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=581
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=721
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=713
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=691
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=588
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=684
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=441
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=497
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=634
#   return f(*args, **kwargs)

# %% [markdown]
# # Decision Tree Model:

# %%
X_train, X_test, y_train, y_test = train_test_split(features,df['label'], test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=20)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9803921568627451

# %% [markdown]
# # Test Model:

# %% [markdown]
# ## Data Frame Test

# %%
filelist = os.listdir('voice_dataset//test') 

#read them into pandas
df_test = pd.DataFrame(filelist)
df_test = df_test.rename(columns={0:'file'})
df_test
# Out:
#                       file
# 0     dina_out_dataset.wav
# 1               other1.wav
# 2               other2.wav
# 3  romisaa_out_dataset.wav
# 4        romisaa_whats.wav
# 5       youssef_whats1.wav
# 6       youssef_whats2.wav

# %% [markdown]
# ## Extract Features Test Function

# %% [markdown]
# ## Prediction

# %%
name = "test"
features_label2 = df_test.apply(extract_features, axis=1)
features=feat(features_label2)
y_pred = clf.predict(features)
y_pred
# Out:
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=910
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=552
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=566
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=712
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=356
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=551
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=585
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=991
#   return f(*args, **kwargs)
# C:\Users\Function\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=496
#   return f(*args, **kwargs)
# array(['0', '3', '3', '1', '2', '2', '2'], dtype=object)
